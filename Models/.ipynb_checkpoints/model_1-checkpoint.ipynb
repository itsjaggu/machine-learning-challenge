# %%
# Update sklearn to prevent version mismatches
# !pip install sklearn --upgrade
# Out:
# Requirement already up-to-date: sklearn in c:\programdata\anaconda3\lib\site-packages (0.0)
# ...

# %%
# install joblib. This will be used to save the model. 
# !pip install joblib

# %%
import pandas as pd

# %% [markdown]
# # Read the CSV and Perform Basic Data Cleaning

# %%
#Readin Exoplanet data
df = pd.read_csv("exoplanet_data.csv")
# Drop the null columns where all values are null
df = df.dropna(axis='columns', how='all')
# Drop the null rows
df = df.dropna()
df.head()
# Out:
#   koi_disposition  koi_fpflag_nt  koi_fpflag_ss  koi_fpflag_co  koi_fpflag_ec  \
# 0       CONFIRMED              0              0              0              0
# 1  FALSE POSITIVE              0              1              0              0
# 2  FALSE POSITIVE              0              1              0              0
# 3       CONFIRMED              0              0              0              0
# 4       CONFIRMED              0              0              0              0
#
#    koi_period  koi_period_err1  koi_period_err2  koi_time0bk  \
# 0   54.418383     2.479000e-04    -2.479000e-04   162.513840
# 1   19.899140     1.490000e-05    -1.490000e-05   175.850252
# 2    1.736952     2.630000e-07    -2.630000e-07   170.307565
# 3    2.525592     3.760000e-06    -3.760000e-06   171.595550
# 4    4.134435     1.050000e-05    -1.050000e-05   172.979370
#
#    koi_time0bk_err1  ...  koi_steff_err2  koi_slogg  koi_slogg_err1  \
# ...

# %%
#Getting column names
df.columns
# Out:
# Index(['koi_disposition', 'koi_fpflag_nt', 'koi_fpflag_ss', 'koi_fpflag_co',
#        'koi_fpflag_ec', 'koi_period', 'koi_period_err1', 'koi_period_err2',
#        'koi_time0bk', 'koi_time0bk_err1', 'koi_time0bk_err2', 'koi_impact',
#        'koi_impact_err1', 'koi_impact_err2', 'koi_duration',
#        'koi_duration_err1', 'koi_duration_err2', 'koi_depth', 'koi_depth_err1',
#        'koi_depth_err2', 'koi_prad', 'koi_prad_err1', 'koi_prad_err2',
#        'koi_teq', 'koi_insol', 'koi_insol_err1', 'koi_insol_err2',
#        'koi_model_snr', 'koi_tce_plnt_num', 'koi_steff', 'koi_steff_err1',
#        'koi_steff_err2', 'koi_slogg', 'koi_slogg_err1', 'koi_slogg_err2',
#        'koi_srad', 'koi_srad_err1', 'koi_srad_err2', 'ra', 'dec',
#        'koi_kepmag'],
#       dtype='object')

# %% [markdown]
# # Select your features (columns)

# %%
# Set features. This will also be used as x values in model computation.
selected_features = df[['koi_fpflag_nt'
                        ,'koi_fpflag_ss'
                        ,'koi_fpflag_co'
                        ,'koi_fpflag_ec'
                        ,'koi_period'
                        ,'koi_time0bk'
                        ,'koi_impact'
                        ,'koi_duration'
                        ,'koi_depth'
                        ,'koi_prad'
                        ,'koi_teq'
                        ,'koi_insol'
                        ,'koi_model_snr'
                        ,'koi_steff'
                        ,'koi_slogg'
                        ,'koi_srad'
                        ,'ra'
                        ,'dec'
                        ,'koi_kepmag']]
selected_features.head()
# Out:
#    koi_fpflag_nt  koi_fpflag_ss  koi_fpflag_co  koi_fpflag_ec  koi_period  \
# 0              0              0              0              0   54.418383
# 1              0              1              0              0   19.899140
# 2              0              1              0              0    1.736952
# 3              0              0              0              0    2.525592
# 4              0              0              0              0    4.134435
#
#    koi_time0bk  koi_impact  koi_duration  koi_depth  koi_prad  koi_teq  \
# 0   162.513840       0.586       4.50700      874.8      2.83      443
# 1   175.850252       0.969       1.78220    10829.0     14.60      638
# 2   170.307565       1.276       2.40641     8079.2     33.46     1395
# 3   171.595550       0.701       1.65450      603.3      2.75     1406
# 4   172.979370       0.762       3.14020      686.0      2.77     1160
#
#    koi_insol  koi_model_snr  koi_steff  koi_slogg  koi_srad         ra  \
# ...

# %% [markdown]
# # Create a Train Test Split

# %%
# scikit-learn import and splitting data in Test-Train
from sklearn.model_selection import train_test_split

X = selected_features
y = df['koi_disposition'].values

X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=43, stratify = y)

# %%
X_train.head()
# Out:
#       koi_fpflag_nt  koi_fpflag_ss  koi_fpflag_co  koi_fpflag_ec  koi_period  \
# 3322              0              0              1              1    0.814279
# 6714              0              1              0              0    4.254418
# 5473              0              1              0              0   18.611957
# 6564              1              0              0              0  277.251180
# 6256              1              0              0              0   76.379240
#
#       koi_time0bk  koi_impact  koi_duration  koi_depth  koi_prad  koi_teq  \
# 3322   131.648060      0.4510       2.08700       72.0      0.76     1762
# 6714   133.837647      1.1650       6.55436   294550.0    133.79     1360
# 5473   133.866199      0.9520       4.24721   124830.0     65.50      829
# 6564   400.039500      0.9320       8.74200     1517.4      5.02      304
# 6256   205.061200      0.7333       0.64500      276.3      1.73      406
#
# ...

# %% [markdown]
# # Pre-processing
#
# Scaling the data using the MinMaxScaler and performing some feature selection

# %%
# Scaling data
from sklearn.preprocessing import MinMaxScaler

X_scaler = MinMaxScaler().fit(X_train)

X_train_scaled = X_scaler.transform(X_train)
X_test_scaled = X_scaler.transform(X_test)

# %% [markdown]
# # Train the Model

# %%
# Decision Tree model
from sklearn import tree

dt = tree.DecisionTreeClassifier()
dt = dt.fit(X_train_scaled, y_train)

# %%
print(f"Training Data Score: {dt.score(X_train_scaled, y_train)}")
print(f"Testing Data Score: {dt.score(X_test_scaled, y_test)}")
# Out:
# Training Data Score: 1.0
# Testing Data Score: 0.851258581235698

# %% [markdown]
# # Hyperparameter Tuning
#
# Using `GridSearchCV` to tune the model's parameters

# %%
# Creating the GridSearchCV model
from sklearn.model_selection import GridSearchCV
param_grid = {'max_depth' : [5,7,10,20,30,40,50]}
grid = GridSearchCV(dt, param_grid, verbose = 3)

# %%
# Train the model with GridSearch
grid.fit(X_train_scaled, y_train)
# Out:
# Fitting 5 folds for each of 7 candidates, totalling 35 fits
# [CV] max_depth=5 .....................................................
# [CV] ......................... max_depth=5, score=0.888, total=   0.0s
# [CV] max_depth=5 .....................................................
# [CV] ......................... max_depth=5, score=0.867, total=   0.0s
# [CV] max_depth=5 .....................................................
# [CV] ......................... max_depth=5, score=0.887, total=   0.0s
# [CV] max_depth=5 .....................................................
# [CV] ......................... max_depth=5, score=0.884, total=   0.0s
# [CV] max_depth=5 .....................................................
# [CV] ......................... max_depth=5, score=0.860, total=   0.0s
# [CV] max_depth=7 .....................................................
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# ...

# %%
print(grid.best_params_)
print(grid.best_score_)
# Out:
# {'max_depth': 7}
# 0.8798383047467961

# %%
from sklearn.metrics import classification_report
print(classification_report(dt.predict(X_test), y_test))
# Out:
#                 precision    recall  f1-score   support
#
#      CANDIDATE       0.00      0.00      0.00         0
#      CONFIRMED       0.98      0.41      0.57      1092
# FALSE POSITIVE       0.74      0.98      0.84       656
#
#       accuracy                           0.62      1748
#      macro avg       0.57      0.46      0.47      1748
#   weighted avg       0.89      0.62      0.67      1748
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\metrics\_classification.py:1221: UndefinedMetricWarning: Recall and F-score are ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %%
# Ranking Feature based on their correlation
ranked_features = sorted(zip(dt.feature_importances_, selected_features.columns.values), reverse=True)
ranked_features
# Out:
# [(0.19068884542343384, 'koi_fpflag_nt'),
#  (0.18152618738779347, 'koi_fpflag_co'),
#  (0.1736947985372159, 'koi_fpflag_ss'),
#  (0.15010366365926803, 'koi_model_snr'),
#  (0.03974466433032052, 'koi_impact'),
#  (0.032580871316701975, 'koi_fpflag_ec'),
#  (0.029281802350671682, 'koi_duration'),
#  (0.025298538624535457, 'koi_period'),
#  (0.023856273028463486, 'koi_prad'),
#  (0.022122572142467593, 'ra'),
#  (0.021832165675497357, 'koi_time0bk'),
#  (0.02181115831237049, 'koi_kepmag'),
#  (0.017352829790432015, 'koi_steff'),
#  (0.01701846453419406, 'dec'),
#  (0.015940568503423617, 'koi_srad'),
#  (0.014470852455145334, 'koi_depth'),
#  (0.009614218731385559, 'koi_teq'),
#  (0.009303417650848961, 'koi_slogg'),
#  (0.0037581075458305796, 'koi_insol')]

# %%
# Removing Bootom 5 features, having least impact to y.
refined_features = selected_features
for n in range(0, 4):
    refined_features = refined_features.drop(ranked_features[-n-1][1], axis = 1)
    
refined_features
# Out:
#       koi_fpflag_nt  koi_fpflag_ss  koi_fpflag_co  koi_fpflag_ec  koi_period  \
# 0                 0              0              0              0   54.418383
# 1                 0              1              0              0   19.899140
# 2                 0              1              0              0    1.736952
# 3                 0              0              0              0    2.525592
# 4                 0              0              0              0    4.134435
# ...             ...            ...            ...            ...         ...
# 6986              0              0              0              1    8.589871
# 6987              0              1              1              0    0.527699
# 6988              0              0              0              0    1.739849
# 6989              0              0              1              0    0.681402
# 6990              0              0              1              1    4.856035
#
# ...

# %%
# Running Decision Tree again with outputs in above step
X2 = refined_features
X2_train, X2_test, y2_train, y2_test = train_test_split(X2, y, random_state=32, stratify = y)
X2_scaler = MinMaxScaler().fit(X2_train)

X2_train_scaled = X2_scaler.transform(X2_train)
X2_test_scaled = X2_scaler.transform(X2_test)

dt2 = tree.DecisionTreeClassifier()
dt2 = dt2.fit(X2_train_scaled, y2_train)

print(f"Training Data Score: {dt2.score(X2_train_scaled, y2_train)}")
print(f"Testing Data Score: {dt2.score(X2_test_scaled, y2_test)}")
print(classification_report(dt2.predict(X2_test), y2_test))
# Out:
# Training Data Score: 1.0
# Testing Data Score: 0.8495423340961098
#                 precision    recall  f1-score   support
#
#      CANDIDATE       0.03      0.42      0.06        31
#      CONFIRMED       0.95      0.41      0.57      1044
# FALSE POSITIVE       0.75      0.98      0.85       673
#
#       accuracy                           0.63      1748
#      macro avg       0.58      0.60      0.49      1748
#   weighted avg       0.86      0.63      0.67      1748

# %%
sorted(zip(dt2.feature_importances_, selected_features.columns.values), reverse=True)
# Out:
# [(0.1955927064632888, 'koi_fpflag_nt'),
#  (0.1772183334835064, 'koi_fpflag_co'),
#  (0.17114035929275284, 'koi_fpflag_ss'),
#  (0.15736574734205, 'koi_prad'),
#  (0.03780753360665257, 'koi_impact'),
#  (0.03621224378020223, 'koi_fpflag_ec'),
#  (0.03393307918977239, 'koi_period'),
#  (0.028720757971990033, 'koi_steff'),
#  (0.028163190549643793, 'koi_duration'),
#  (0.027709039912602984, 'koi_model_snr'),
#  (0.027593738199696093, 'koi_depth'),
#  (0.02229526569874712, 'koi_time0bk'),
#  (0.019787089873995686, 'koi_insol'),
#  (0.01851672275814347, 'koi_teq'),
#  (0.017944191876955794, 'koi_slogg')]

# %% [markdown]
# # Save the Model

# %%
# saving the model
import joblib
filename = 'Jagrati_Joshi_Model1_DecisionTree.sav'
joblib.dump(dt, filename)
# Out:
# ['Jagrati_Joshi_Model1_DecisionTree.sav']
